# %%
import os
import sys
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
base_path = '/'.join(os.path.abspath('.').split('/')[:-1])
data_path = base_path + '/data'
county_path = data_path + '/counties'
house_path = data_path + '/house'
senate_path = data_path + '/senate'

# %%
senate = gpd.read_file(senate_path + '/MO_2012_Senate_Districts.shp')
senate.columns
# Out:
# Index(['FID', 'DISTRICT', 'POPULATION', 'IDEAL', 'DEVIATION', 'WHITE', 'BLACK',
#        'AMINDIAN', 'ASIAN', 'HAWAIIAN', 'OTHER', 'MULTI_RACE', 'AP_BLK',
#        'HISPANIC', 'NOT_HISP', 'NH_WHT', 'MINORITY', 'POP_18PLUS',
#        'WHT_18PLUS', 'BLK_18PLUS', 'IND_18PLUS', 'ASN_18PLUS', 'HWN_18PLUS',
#        'OTH_18PLUS', 'MR_18PLUS', 'APB_18PLUS', 'H_18PLUS', 'NH_18PLUS',
#        'NH_W18PLUS', 'MIN_18PLUS', 'Shape__Are', 'Shape__Len', 'geometry'],
#       dtype='object')

# %%
house = gpd.read_file(house_path + '/MO_2011_House_Districts.shp')
house.columns
# Out:
# Index(['FID', 'DISTRICT', 'POPULATION', 'IDEAL', 'DEVIATION', 'WHITE', 'BLACK',
#        'AMINDIAN', 'ASIAN', 'HAWAIIAN', 'OTHER', 'MULTI_RACE', 'AP_BLK',
#        'HISPANIC', 'NOT_HISP', 'NH_WHT', 'MINORITY', 'POP_18PLUS',
#        'WHT_18PLUS', 'BLK_18PLUS', 'IND_18PLUS', 'ASN_18PLUS', 'HWN_18PLUS',
#        'OTH_18PLUS', 'MR_18PLUS', 'APB_18PLUS', 'HISP_18PLU', 'NH_18PLUS',
#        'NH_W18PLUS', 'MIN_18PLUS', 'Shape__Are', 'Shape__Len', 'geometry'],
#       dtype='object')

# %%
senate.plot(cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
house.plot(cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
senate.loc[:,['DISTRICT','POPULATION', 'WHITE', 'BLACK', 'HISPANIC']]
# Out:
#     DISTRICT  POPULATION   WHITE   BLACK  HISPANIC
# 0          1      179606  163667    7598      3974
# 1          2      181073  165576    6832      4528
# 2          3      173099  165495    3987      1866
# 3          4      176107  105300   60500      4743
# 4          5      177016   63817   98794      7293
# 5          6      175186  159859    9402      3400
# 6          7      168435  113592   39475     13283
# 7          8      168462  149531    9900      6960
# 8          9      168649   52115   98291     17195
# 9         10      176016  164448    5748      3618
# 10        11      168612  135835   13701     18996
# 11        12      181976  173503    3145      4242
# 12        13      171967   70297   95457      2619
# 13        14      171753   60530  101807      4322
# 14        15      178836  164880    3243      3477
# 15        16      181785  163532    7293      7155
# 16        17      176894  151178   10967     11863
# ...
